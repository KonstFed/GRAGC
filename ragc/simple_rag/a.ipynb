# %%
from ragc.simple_rag.dataset import CodeRepoDataset, CodeRepoDatasetConfig
from ragc.simple_rag.pipeline import SimpleRAGPipelineConfig

# %%
from pathlib import Path
from ragc.llm.huggingface import HuggingFaceEmbedderConfig

# %%
embedder_cfg = HuggingFaceEmbedderConfig(
        model_name="microsoft/unixcoder-base",
        max_batch_size=1024,
        max_length=1024,
        store_in_gpu=False,
    )


embedder = embedder_cfg.create()

# %%
all_repos = [str(p) for p in Path("/home/jovyan/work/diplom/RAGC/data/Source_Code").iterdir()]

# %%
ds = CodeRepoDataset(all_repos, Path("/home/jovyan/work/diplom/RAGC/data/simple_cache"), embedder=embedder)

# %%
ds.repo_paths
# Out:
# ['/home/jovyan/work/diplom/RAGC/data/Source_Code/Database',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/Multimedia',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/Security',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/Scientific-Engineering',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/System',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/Software-Development',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/Internet',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/Communications',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/Utilities',
#  '/home/jovyan/work/diplom/RAGC/data/Source_Code/Text-Processing']

# %%
from ragc.test.test_config import SimpleRAGInferenceConfig
from ragc.llm.ollama import OllamaGeneratorConfig

# %%
ds_cfg = CodeRepoDatasetConfig(
    cache_path=Path("/home/jovyan/work/diplom/RAGC/data/simple_cache"),
    embedder=embedder_cfg,
)

generator_cfg = OllamaGeneratorConfig(
    model="deepseek-r1",
)

pipeline_cfg = SimpleRAGPipelineConfig(
    type="simple_rag_pipeline",
    embedder=embedder_cfg,
    generator=generator_cfg,
)

test_cfg = SimpleRAGInferenceConfig(
    dataset=ds_cfg,
    pipeline=pipeline_cfg,
    task_path=Path("/home/jovyan/work/diplom/RAGC/data/data.jsonl"),
    repos_path=Path("/home/jovyan/work/diplom/RAGC/data/Source_Code"),
)

# %%
from ragc.utils import save_config

save_config(test_cfg, "/home/jovyan/work/diplom/RAGC/data/test_simple_rag.yaml")
# Out:
# /home/jovyan/.cache/pypoetry/virtualenvs/ragc-Ja1e_PLX-py3.11/lib/python3.11/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `CompletionGeneratorConfig` - serialized value may not be as expected [input_value=OllamaGeneratorConfig(oll...4', model='deepseek-r1'), input_type=OllamaGeneratorConfig])
#   PydanticSerializationUnexpectedValue(Expected `<class 'pydantic.networks.HttpUrl'>` but got `<class 'str'>` with value `'localhost:11434'` - serialized value may not be as expected.)
#   PydanticSerializationUnexpectedValue(Expected `<class 'pydantic.networks.HttpUrl'>` but got `<class 'str'>` with value `'localhost:11434'` - serialized value may not be as expected.)
#   return self.__pydantic_serializer__.to_python(

# %%
inference = test_cfg.create()

# %%
bar = inference.generate_completion()
next(bar)
# Out:
#   0%|          | 0/1825 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 bar = inference.generate_completion()
# ----> 2 next(bar)
#
# File ~/work/diplom/RAGC/ragc/test/test_config.py:317, in SimpleRAGInference.generate_completion(self, progress_bar)
#     310 repo_name = Path(task["project_path"]).parts[-1]
#     311 # перенесли внутри SimpleRAGPipeline
#     312 # prompt = build_prompt(
#     313 #     task=task,
#     314 #     repos_path=self.repos_path,
#     315 # )
# --> 317 generation = self(repo_name=repo_name, prompt=task)
#     318 result = {
#     319     "namespace": task["namespace"],
#     320     "completion": generation,
#     321 }
#     322 yield result
#
# File ~/work/diplom/RAGC/ragc/test/test_config.py:300, in SimpleRAGInference.__call__(self, repo_name, prompt)
#     299 def __call__(self, repo_name: str, prompt: str) -> tuple[str, dict]:
# --> 300     ds = self.dataset_cfg.create(repo_name=repo_name)
#     301     inference = self.inference_cfg.create(ds)
#     302     inference.query(question=prompt)
#
# File ~/work/diplom/RAGC/ragc/simple_rag/dataset.py:124, in CodeRepoDatasetConfig.create(self, repo_name)
#     122 def create(self, repo_name: str) -> CodeRepoDataset:
#     123     _embedder = self.embedder.create()
# --> 124     CodeRepoDataset(
#     125         repo_paths=repo_name,
#     126         cache_dir=self.cache_path,
#     127         embedder=_embedder,
#     128     )
#
# File ~/work/diplom/RAGC/ragc/simple_rag/dataset.py:32, in CodeRepoDataset.__init__(self, repo_paths, cache_dir, embedder, max_lines, use_cache)
#      29 self.repo_to_indices = {}
#      31 self.cache_dir.mkdir(parents=True, exist_ok=True)
# ---> 32 self._load_all_repos()
#
# File ~/work/diplom/RAGC/ragc/simple_rag/dataset.py:51, in CodeRepoDataset._load_all_repos(self)
#      49     repo_data = torch.load(cache_file)
#      50 else:
# ---> 51     repo_data = self._process_repo(repo_path)
#      52     if self.use_cache:
#      53         torch.save(repo_data, cache_file)
#
# File ~/work/diplom/RAGC/ragc/simple_rag/dataset.py:82, in CodeRepoDataset._process_repo(self, repo_path)
#      79             print(f"Error reading {path}: {e}")
#      81 texts = [item["chunk"] for item in repo_data]
# ---> 82 embeddings = self.embedder.embed(texts)
#      84 for i, emb in enumerate(embeddings):
#      85     repo_data[i]["embedding"] = emb
#
# File ~/work/diplom/RAGC/ragc/llm/huggingface.py:41, in HuggingFaceEmbedder.embed(self, inputs)
#      38 batch_size = min(self.max_batch_size, len(inputs))
#      39 embeddings = []
# ---> 41 for i in trange(0, len(inputs), batch_size):
#      42     batch = inputs[i : min(i + batch_size, len(inputs))]
#      43     tokenized_inputs = self.tokenizer(
#      44         batch,
#      45         padding=True,
#    (...)
#      48         max_length=self.max_length,
#      49     ).to(device)
#
# File ~/.cache/pypoetry/virtualenvs/ragc-Ja1e_PLX-py3.11/lib/python3.11/site-packages/tqdm/std.py:1524, in trange(*args, **kwargs)
#    1522 def trange(*args, **kwargs):
#    1523     """Shortcut for tqdm(range(*args), **kwargs)."""
# -> 1524     return tqdm(range(*args), **kwargs)
#
# ValueError: range() arg 3 must not be zero
